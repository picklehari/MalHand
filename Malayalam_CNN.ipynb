# %% [markdown]
# <a href="https://colab.research.google.com/github/picklehari/MalHand/blob/master/Malayalam_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training a Neural Net Model for Alphabets

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Importing Libraries. Inital try with fastai libraries.

# %%
from fastai import *
from fastai.vision import *
from fastai.metrics import error_rate

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
path = "/content/gdrive/My Drive/Data/"
# tfms = ([*rand_pad(padding=1,size=32,mode='zeros')],[])
np.random.seed(52)
data = ImageDataBunch.from_folder(path,ds_tfms=None,size=1024,bs=4).normalize()
data.show_batch(rows=3)

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy,pretrained=False)

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='84' class='' max='4311' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.95% [84/4311 00:26<21:56 14.0201]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot(suggestion=True,show_grid=True,skip_end=15)
# Out:
# Min numerical gradient: 5.25E-05
# Min loss divided by 10: 2.09E-04

# %%
path = "/content/gdrive/My Drive/Handwriting Models"
learn.path = Path(path)

# %%
learn.fit_one_cycle(10,max_lr=slice(5.25e-05,1e-03))
learn.export("resnet_18_non_trained.pkl")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.048027</td>
#       <td>2.818116</td>
#       <td>0.283912</td>
#       <td>27:35</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.660764</td>
#       <td>1.656170</td>
#       <td>0.566421</td>
#       <td>26:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.695215</td>
#       <td>0.758261</td>
#       <td>0.780582</td>
#       <td>26:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.103061</td>
#       <td>0.428105</td>
#       <td>0.869085</td>
#       <td>26:28</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.987578</td>
#       <td>0.279708</td>
#       <td>0.922713</td>
#       <td>26:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.560552</td>
#       <td>0.176095</td>
#       <td>0.948300</td>
#       <td>26:20</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.388016</td>
#       <td>0.126884</td>
#       <td>0.963021</td>
#       <td>26:12</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.391123</td>
#       <td>0.113423</td>
#       <td>0.966001</td>
#       <td>26:07</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.248220</td>
#       <td>0.102155</td>
#       <td>0.968104</td>
#       <td>26:33</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.298010</td>
#       <td>0.103411</td>
#       <td>0.968454</td>
#       <td>26:53</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.path = Path(".")
learn.export("MalHand_18.pkl")

# %%
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='84' class='' max='4311' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.95% [84/4311 00:24<20:11 3.8213]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
pth = Path(".")
img = open_image(pth/"1344.png") 
img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-c62ed7de2cac> in <module>()
#       1 pth = Path(".")
# ----> 2 img = open_image(pth/"1344.png")
#       3 img
#
# /usr/local/lib/python3.6/dist-packages/fastai/vision/image.py in open_image(fn, div, convert_mode, cls, after_open)
#     396     with warnings.catch_warnings():
#     397         warnings.simplefilter("ignore", UserWarning) # EXIF warning from TiffPlugin
# --> 398         x = PIL.Image.open(fn).convert(convert_mode)
#     399     if after_open: x = after_open(x)
#     400     x = pil2tensor(x,np.float32)
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/1344.png'

# %%
interp.plot_top_losses(12)

# %%
interp.plot_confusion_matrix(figsize = (15,15),dpi=60)

# %%
interp.most_confused(min_val= 3)
# Out:
# [('83', '7', 10),
#  ('11', '31', 9),
#  ('10', '39', 5),
#  ('13', '71', 5),
#  ('14', '49', 4),
#  ('49', '14', 4),
#  ('49', '15', 4),
#  ('7', '83', 4),
#  ('72', '32', 4),
#  ('73', '29', 4),
#  ('83', '85', 4),
#  ('10', '37', 3),
#  ('14', '15', 3),
#  ('31', '11', 3),
#  ('63', '35', 3),
#  ('67', '71', 3),
#  ('69', '24', 3)]

# %%
top_losses,top_idx = interp.top_losses()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-df2e6281479b> in <module>()
# ----> 1 barplot(top_losses,top_idx)
#
# NameError: name 'barplot' is not defined

# %%
learn = load_learner( = path'.',file="MalHand_18.pkl")

# %%
learn.lr_find()
# learn.recorder.plot()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-d1e70c13c104> in <module>()
# ----> 1 learn.lr_find()
#       2 # learn.recorder.plot()
#
# /usr/local/lib/python3.6/dist-packages/fastai/train.py in lr_find(learn, start_lr, end_lr, num_it, stop_div, wd)
#      38     end_lr = np.array(end_lr) if is_listy(end_lr) else end_lr
#      39     cb = LRFinder(learn, start_lr, end_lr, num_it, stop_div)
# ---> 40     epochs = int(np.ceil(num_it/len(learn.data.train_dl))) * (num_distrib() or 1)
#      41     learn.fit(epochs, start_lr, callbacks=[cb], wd=wd)
#      42
#
# ZeroDivisionError: division by zero

# %%
learn.recorder.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-81a9773e4aba> in <module>()
# ----> 1 learn.recorder.plot()
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in plot(self, skip_start, skip_end, suggestion, return_fig, show_grid, **kwargs)
#     541              **kwargs)->Optional[plt.Figure]:
#     542         "Plot learning rate and losses, trimmed between `skip_start` and `skip_end`. Optionally plot and return min gradient"
# --> 543         lrs = self._split_list(self.lrs, skip_start, skip_end)
#     544         losses = self._split_list(self.losses, skip_start, skip_end)
#     545         losses = [x.item() for x in losses]
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in __getattr__(self, k)
#     441         setattr(self.learn, self.cb_name, self)
#     442
# --> 443     def __getattr__(self,k): return getattr(self.learn, k)
#     444     def __setstate__(self,data:Any): self.__dict__.update(data)
#     445
#
# AttributeError: 'Learner' object has no attribute 'lrs'

# %%
learn.unfreeze()
learn.fit_one_cycle(2,max_lr=slice(1e-6,1e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.179288</td>
#       <td>4.587296</td>
#       <td>0.086050</td>
#       <td>25:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.207184</td>
#       <td>6.845227</td>
#       <td>0.086926</td>
#       <td>24:57</td>
#     </tr>
#   </tbody>
# </table>
